# %%
import csv

df = open("Iconic_Songs_Dataset.csv")
csvreader = csv.reader(df)
header = next(csvreader)
print(header)
# Out:
# ['Title', 'Artist', 'Genre', 'ReleaseDate', 'Duration', 'Album', 'Popularity']

# %%
import pandas as pd

# load data from a CSV file
df = pd.read_csv('Iconic_Songs_Dataset.csv')
df.loc[0:5]
df.describe()
# Out:
#        Popularity
# count  100.000000
# mean    91.710000
# std      3.806679
# min     84.000000
# 25%     89.000000
# 50%     92.000000
# 75%     95.000000
# max     99.000000

# %%
df = pd.read_csv('Iconic_Songs_Dataset.csv')
df.isnull().sum()
# Out:
# Title          0
# Artist         0
# Genre          0
# ReleaseDate    0
# Duration       0
# Album          2
# Popularity     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

genre_popularity = df.groupby('Genre')['Popularity'].mean()
# Bar plot: Average popularity by genre
genre_popularity.plot(kind='bar')
plt.ylabel('Average Popularity')
plt.title('Average Popularity by Genre')
plt.show()

# Pie chart: Genre distribution
genre_distribution = df['Genre'].value_counts()
genre_distribution.plot(kind='pie', autopct='%1.1f%%')
plt.title('Genre Distribution')
plt.show()

# %%
# Top 10 songs by popularity
top_10_songs = df.nlargest(10, 'Popularity')
print(top_10_songs)

# Filter songs released in 2024
songs_2024 = df[df['ReleaseDate'] == 2024]
print(songs_2024)

# Filter songs by genre 'Pop'
pop_songs = df[df['Genre'] == 'K-Pop']
print(pop_songs)
# Out:
#               Title                         Artist    Genre ReleaseDate  \
# 35         Dynamite                            BTS    K-Pop  2024-02-15
# 61         Señorita  Shawn Mendes & Camila Cabello      Pop  2024-06-25
# 78    Thank U, Next                  Ariana Grande      Pop  2024-09-20
# 14       Easy On Me                          Adele      Pop  2024-07-22
# 33  Don't Start Now                       Dua Lipa      Pop  2024-02-03
# 60    Old Town Road                      Lil Nas X  Hip-Hop  2024-06-20
# 81          7 Rings                  Ariana Grande      Pop  2024-10-05
# 85      Uptown Funk     Mark Ronson ft. Bruno Mars      Pop  2024-12-25
# 9   drivers license                 Olivia Rodrigo      Pop  2024-05-05
# 48        Sunflower         Post Malone & Swae Lee      Pop  2024-04-20
#
#    Duration                 Album  Popularity
# 35     3:19                    BE          99
# 61     3:11          Shawn Mendes          99
# 78     3:27         Thank U, Next          99
# 14     3:45                    30          98
# 33     3:03      Future Nostalgia          98
# 60     2:37                  7 EP          98
# 81     2:58         Thank U, Next          98
# 85     4:30        Uptown Special          98
# 9      4:02                  SOUR          97
# 48     2:38  Hollywood's Bleeding          97
#            Title Artist  Genre ReleaseDate Duration   Album  Popularity
# 8         Butter    BTS  K-Pop  2024-04-22     2:44  Butter          96
# 35      Dynamite    BTS  K-Pop  2024-02-15     3:19      BE          99
# 39  Life Goes On    BTS  K-Pop  2024-03-05     3:27      BE          93

# %%
# Trend of song releases over time
release_trend = df['ReleaseDate'].value_counts().sort_index()
release_trend.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.title('Trend of Song Releases Over Time')
plt.show()

# Trend of average popularity over time
popularity_trend = df.groupby('ReleaseDate')['Popularity'].mean()
popularity_trend.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Average Popularity')
plt.title('Trend of Average Popularity Over Time')
plt.show()
